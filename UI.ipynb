# %% [markdown]
# ### Loading Libraries

# %%
import kagglehub

# %% [markdown]
# ### Loading datafrom kaggle

# %%
path = kagglehub.dataset_download("khizarjamshaid/pakistan-currency-dataset")
print("Path to dataset files:", path)
